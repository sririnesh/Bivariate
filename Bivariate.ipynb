# %%
import pandas as pd
# Out:
# C:\Users\sripriya\AppData\Local\Temp\ipykernel_15612\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dataset=pd.read_csv('preplacementdata.csv')

# %%
dataset
# Out:
#        Sno  10th %  12th %  Degree %  Mba %    salary Gender SSC Board  \
# 0      1.0   67.00   91.00     58.00  58.80  270000.0      M    Others
# 1      2.0   79.33   78.33     77.48  66.28  200000.0      M   Central
# 2      3.0   65.00   68.00     64.00  57.80  250000.0      M   Central
# 3      4.0   56.00   52.00     52.00  59.43       0.0      M   Central
# 4      5.0   85.80   73.60     73.30  55.50  425000.0      M   Central
# ..     ...     ...     ...       ...    ...       ...    ...       ...
# 210  211.0   80.60   82.00     77.60  74.49  400000.0      M    Others
# 211  212.0   58.00   60.00     72.00  53.62  275000.0      M    Others
# 212  213.0   67.00   67.00     73.00  69.72  295000.0      M    Others
# 213  214.0   74.00   66.00     58.00  60.23  204000.0      F    Others
# 214  215.0   62.00   58.00     53.00  60.22       0.0      M   Central
#
#     HSC Board 12th Stream Degree stream Work exp specialisation      status
# ...

# %%
dataset.isnull().sum()
# Out:
# Sno               0
# 10th %            0
# 12th %            0
# Degree %          0
# Mba %             0
# salary            0
# Gender            0
# SSC Board         0
# HSC Board         0
# 12th Stream       0
# Degree stream     0
# Work exp          0
# specialisation    0
# status            0
# dtype: int64

# %%
dataset.cov()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset.cov()
#
# File ~\.conda\envs\aiml\Lib\site-packages\pandas\core\frame.py:11177, in DataFrame.cov(self, min_periods, ddof, numeric_only)
#   11175 cols = data.columns
#   11176 idx = cols.copy()
# > 11177 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11179 if notna(mat).all():
#   11180     if min_periods is not None and min_periods > len(mat):
#
# File ~\.conda\envs\aiml\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# ...
